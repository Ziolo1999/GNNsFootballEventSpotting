# %%
import os
os.chdir("../")
from data_management.DataManager import CALFData, collateGCN
import numpy as np
import torch 
from Model import ContextAwareModel
from helpers.loss import ContextAwareLoss, SpottingLoss
from modules.train import trainer
import pickle
from dataclasses import dataclass
import matplotlib.pyplot as plt
from modules.Visualiser import collateVisGCN, Visualiser, VisualiseDataset
import seaborn as sns
from helpers.classes import EVENT_DICTIONARY_V2_ALIVE as event_enc
from helpers.classes import get_K_params
import torch.nn as nn

# %%
@dataclass
class Args:
    receptive_field = 12
    fps = 5
    chunks_per_epoch = 1824
    class_split = "alive"
    chunk_size = 60
    batch_size = 32
    input_channel = 13
    feature_multiplier=1
    backbone_player = "GCN"
    max_epochs=180
    load_weights=None
    model_name="Testing_Model"
    dim_capsule=16
    lambda_coord=5.0
    lambda_noobj=0.5
    patience=25
    LR=1e-03
    GPU=0 
    max_num_worker=1
    loglevel='INFO'
    annotation_nr = 1
    K_parameters = get_K_params(chunk_size)
    focused_annotation = "Duel"
    generate_augmented_data = True
    sgementation_path = "models/gridsearch5.pth.tar"
    freeze_model = True
    generate_artificial_targets = False

# %%
args = Args
collate_fn = collateGCN
list_anns = list(event_enc.keys())

for ann in list_anns:
    print(f"\n {ann}")
    args.focused_annotation = ann
    
    # Read data for specific annotation
    train_dataset = CALFData(split="train", args=args)
    validation_dataset = CALFData(split="validate", args=args)

    train_loader = torch.utils.data.DataLoader(train_dataset,
                batch_size=args.batch_size, shuffle=True, collate_fn=collate_fn)

    validate_loader = torch.utils.data.DataLoader(validation_dataset,
                batch_size=args.batch_size, shuffle=True, collate_fn=collate_fn)

    # Load pre-trained model and adjust it
    model = torch.load(args.sgementation_path)
    model.num_classes = 1
    model.conv_seg = nn.Conv2d(in_channels=152, out_channels=model.dim_capsule, kernel_size=(model.kernel_seg_size,1))
    
    criterion = ContextAwareLoss(K=train_dataset.K_parameters)
    optimizer = torch.optim.Adam(model.parameters(), lr=args.LR, 
                                betas=(0.9, 0.999), eps=1e-07, 
                                weight_decay=0, amsgrad=False)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', verbose=True, patience=args.patience)

    losses = trainer(train_loader, validate_loader,
                        model, optimizer, scheduler, 
                        criterion,
                        model_name=args.model_name,
                        max_epochs=args.max_epochs, 
                        save_dir=f"models/finetuned_{ann}.pth.tar")

    with open(f'results/finetuned_{ann}.pkl', 'wb') as file:
        pickle.dump(losses, file)
    
    del train_dataset,validation_dataset,train_loader, validate_loader,model
# Out:
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
#  Pressure
# Data preprocessing: 100%|██████████| 10/10 [03:13<00:00, 19.40s/it]
# Get labels & features: 100%|██████████| 40/40 [12:23<00:00, 18.59s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 2/2 [00:35<00:00, 17.65s/it]
# Get labels & features: 100%|██████████| 8/8 [02:09<00:00, 16.20s/it]
# Train 1: Time 6.705s (it:6.759s) Data:1.249s (it:1.123s) Loss 3.5814e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:22<00:00,  6.71s/it]
# Evaluate 1: Time 3.676s (it:3.879s) Data:0.970s (it:0.756s) Loss 6.2582e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:29<00:00,  3.68s/it]
# Train 2: Time 6.214s (it:5.051s) Data:1.186s (it:1.062s) Loss 3.3227e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:54<00:00,  6.21s/it]
# Evaluate 2: Time 3.322s (it:2.459s) Data:0.908s (it:0.759s) Loss 5.6189e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:09<00:00,  3.32s/it]
# Train 3: Time 6.325s (it:6.737s) Data:1.205s (it:1.051s) Loss 3.3420e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:00<00:00,  6.32s/it]
# Evaluate 3: Time 3.375s (it:2.471s) Data:0.920s (it:0.735s) Loss 5.2843e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:12<00:00,  3.38s/it]
# Train 4: Time 6.435s (it:5.187s) Data:1.272s (it:1.104s) Loss 3.3050e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:06<00:00,  6.44s/it]
# Evaluate 4: Time 3.317s (it:2.554s) Data:0.899s (it:0.737s) Loss 5.3094e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:09<00:00,  3.32s/it]
# Train 5: Time 6.366s (it:5.063s) Data:1.221s (it:1.048s) Loss 3.3059e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:02<00:00,  6.37s/it]
# Evaluate 5: Time 3.226s (it:2.309s) Data:0.921s (it:0.712s) Loss 5.3729e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:03<00:00,  3.23s/it]
# Train 6: Time 6.481s (it:5.417s) Data:1.205s (it:1.132s) Loss 3.1791e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:09<00:00,  6.48s/it]
# Evaluate 6: Time 3.261s (it:2.620s) Data:0.932s (it:0.718s) Loss 5.1761e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:05<00:00,  3.26s/it]
# Train 7: Time 6.817s (it:7.032s) Data:1.340s (it:1.291s) Loss 3.2000e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:28<00:00,  6.82s/it]
# Evaluate 7: Time 3.809s (it:2.745s) Data:0.940s (it:0.799s) Loss 5.3032e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:37<00:00,  3.81s/it]
# Train 8: Time 6.446s (it:5.288s) Data:1.260s (it:1.099s) Loss 3.1787e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:07<00:00,  6.45s/it]
# Evaluate 8: Time 3.271s (it:3.829s) Data:0.927s (it:0.723s) Loss 5.0571e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:06<00:00,  3.27s/it]
# Train 9: Time 6.488s (it:6.438s) Data:1.265s (it:1.043s) Loss 3.2936e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:09<00:00,  6.49s/it]
# Evaluate 9: Time 3.938s (it:2.836s) Data:0.956s (it:0.792s) Loss 4.7976e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:44<00:00,  3.94s/it]
# Train 10: Time 6.715s (it:5.057s) Data:1.322s (it:1.061s) Loss 3.2714e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:22<00:00,  6.71s/it]
# Evaluate 10: Time 3.335s (it:2.767s) Data:0.932s (it:0.765s) Loss 4.5859e+00 : 100%|████████████████████████████████████████████| 57/57 [03:10<00:00,  3.34s/it]
# Train 11: Time 6.346s (it:5.135s) Data:1.223s (it:1.098s) Loss 3.1672e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:01<00:00,  6.35s/it]
# Evaluate 11: Time 3.395s (it:5.680s) Data:0.966s (it:2.697s) Loss 5.1898e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.39s/it]
# Train 12: Time 6.329s (it:5.035s) Data:1.236s (it:1.112s) Loss 3.1105e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:00<00:00,  6.33s/it]
# Evaluate 12: Time 3.419s (it:2.658s) Data:0.921s (it:0.755s) Loss 4.6971e+00 : 100%|████████████████████████████████████████████| 57/57 [03:14<00:00,  3.42s/it]
# Train 13: Time 6.466s (it:6.147s) Data:1.253s (it:1.073s) Loss 3.0710e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:08<00:00,  6.47s/it]
# Evaluate 13: Time 3.609s (it:4.086s) Data:0.957s (it:0.785s) Loss 5.1075e+00 : 100%|████████████████████████████████████████████| 57/57 [03:25<00:00,  3.61s/it]
# Train 14: Time 6.708s (it:5.147s) Data:1.312s (it:1.113s) Loss 3.3024e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:22<00:00,  6.71s/it]
# Evaluate 14: Time 3.079s (it:2.339s) Data:0.969s (it:0.728s) Loss 4.3779e+00 : 100%|████████████████████████████████████████████| 57/57 [02:55<00:00,  3.08s/it]
# Train 15: Time 6.234s (it:5.131s) Data:1.233s (it:1.132s) Loss 3.1435e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:55<00:00,  6.23s/it]
# Evaluate 15: Time 3.168s (it:2.641s) Data:0.895s (it:0.735s) Loss 4.8036e+00 : 100%|████████████████████████████████████████████| 57/57 [03:00<00:00,  3.17s/it]
# Train 16: Time 6.531s (it:5.514s) Data:1.242s (it:1.186s) Loss 3.2387e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:12<00:00,  6.53s/it]
# Evaluate 16: Time 3.595s (it:3.604s) Data:0.966s (it:0.820s) Loss 4.8499e+00 : 100%|████████████████████████████████████████████| 57/57 [03:24<00:00,  3.60s/it]
# Train 17: Time 6.528s (it:6.269s) Data:1.323s (it:1.118s) Loss 3.1039e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:12<00:00,  6.53s/it]
# Evaluate 17: Time 3.317s (it:2.594s) Data:0.901s (it:0.750s) Loss 4.9338e+00 : 100%|████████████████████████████████████████████| 57/57 [03:09<00:00,  3.32s/it]
# Train 18: Time 6.446s (it:6.537s) Data:1.283s (it:1.117s) Loss 3.0124e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:07<00:00,  6.45s/it]
# Evaluate 18: Time 4.576s (it:2.691s) Data:1.170s (it:0.855s) Loss 5.2062e+00 : 100%|████████████████████████████████████████████| 57/57 [04:20<00:00,  4.58s/it]
# Train 19: Time 7.222s (it:11.984s) Data:1.396s (it:5.696s) Loss 3.2308e+00 : 100%|██████████████████████████████████████████████| 57/57 [06:51<00:00,  7.22s/it]
# Evaluate 19: Time 3.824s (it:2.578s) Data:0.963s (it:0.785s) Loss 5.0591e+00 : 100%|████████████████████████████████████████████| 57/57 [03:37<00:00,  3.82s/it]
# Train 20: Time 7.097s (it:7.334s) Data:1.323s (it:1.129s) Loss 3.1834e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:44<00:00,  7.10s/it]
# Evaluate 20: Time 4.110s (it:3.803s) Data:1.006s (it:0.839s) Loss 4.5430e+00 : 100%|████████████████████████████████████████████| 57/57 [03:54<00:00,  4.11s/it]
# Train 21: Time 7.254s (it:6.542s) Data:1.417s (it:1.083s) Loss 3.1191e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:53<00:00,  7.25s/it]
# Evaluate 21: Time 3.688s (it:2.586s) Data:0.942s (it:0.775s) Loss 5.0807e+00 : 100%|████████████████████████████████████████████| 57/57 [03:30<00:00,  3.69s/it]
# Train 22: Time 7.195s (it:7.335s) Data:1.362s (it:1.349s) Loss 2.8849e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:50<00:00,  7.20s/it]
# Evaluate 22: Time 3.788s (it:2.521s) Data:1.017s (it:0.842s) Loss 4.8306e+00 : 100%|████████████████████████████████████████████| 57/57 [03:35<00:00,  3.79s/it]
# Train 23: Time 7.080s (it:7.031s) Data:1.373s (it:1.242s) Loss 3.1801e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:43<00:00,  7.08s/it]
# Evaluate 23: Time 3.993s (it:4.083s) Data:1.070s (it:0.876s) Loss 4.5898e+00 : 100%|████████████████████████████████████████████| 57/57 [03:47<00:00,  3.99s/it]
# Train 24: Time 7.192s (it:6.995s) Data:1.397s (it:1.200s) Loss 3.0806e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:49<00:00,  7.19s/it]
# Evaluate 24: Time 3.782s (it:3.635s) Data:1.037s (it:0.783s) Loss 4.9990e+00 : 100%|████████████████████████████████████████████| 57/57 [03:35<00:00,  3.78s/it]
# Train 25: Time 6.839s (it:6.831s) Data:1.302s (it:1.191s) Loss 3.1577e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:29<00:00,  6.84s/it]
# Evaluate 25: Time 3.746s (it:3.757s) Data:1.033s (it:0.848s) Loss 4.7768e+00 : 100%|████████████████████████████████████████████| 57/57 [03:33<00:00,  3.75s/it]
# Train 26: Time 6.839s (it:6.820s) Data:1.315s (it:1.102s) Loss 3.1306e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:29<00:00,  6.84s/it]
# Evaluate 26: Time 3.697s (it:2.513s) Data:0.940s (it:0.777s) Loss 4.9480e+00 : 100%|████████████████████████████████████████████| 57/57 [03:30<00:00,  3.70s/it]
# Train 27: Time 6.566s (it:5.326s) Data:1.261s (it:1.181s) Loss 3.0365e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:14<00:00,  6.57s/it]
# Evaluate 27: Time 3.643s (it:3.861s) Data:0.989s (it:0.727s) Loss 5.1679e+00 : 100%|████████████████████████████████████████████| 57/57 [03:27<00:00,  3.64s/it]
# Train 28: Time 7.239s (it:7.276s) Data:1.370s (it:1.115s) Loss 3.0848e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:52<00:00,  7.24s/it]
# Evaluate 28: Time 4.536s (it:4.121s) Data:1.081s (it:0.916s) Loss 4.5842e+00 : 100%|████████████████████████████████████████████| 57/57 [04:18<00:00,  4.54s/it]
# Train 29: Time 7.351s (it:7.482s) Data:1.408s (it:1.218s) Loss 3.0677e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:59<00:00,  7.35s/it]
# Evaluate 29: Time 4.493s (it:4.695s) Data:1.075s (it:0.963s) Loss 4.6514e+00 : 100%|████████████████████████████████████████████| 57/57 [04:16<00:00,  4.49s/it]
#  Foul Committed
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 10/10 [03:11<00:00, 19.15s/it]
# Get labels & features: 100%|██████████| 40/40 [12:56<00:00, 19.42s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 2/2 [00:38<00:00, 19.26s/it]
# Get labels & features: 100%|██████████| 8/8 [02:21<00:00, 17.63s/it]
# Train 1: Time 7.429s (it:6.737s) Data:1.403s (it:1.067s) Loss 3.7821e+00 : 100%|████████████████████████████████████████████████| 57/57 [07:03<00:00,  7.43s/it]
# Evaluate 1: Time 3.980s (it:2.835s) Data:0.984s (it:0.825s) Loss 5.6710e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:46<00:00,  3.98s/it]
# Train 2: Time 6.373s (it:4.942s) Data:1.237s (it:1.038s) Loss 3.4249e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:03<00:00,  6.37s/it]
# Evaluate 2: Time 3.300s (it:2.444s) Data:0.901s (it:0.748s) Loss 4.5382e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:08<00:00,  3.30s/it]
# Train 3: Time 6.525s (it:11.906s) Data:1.261s (it:5.988s) Loss 3.4312e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:11<00:00,  6.52s/it]
# Evaluate 3: Time 3.306s (it:2.386s) Data:0.893s (it:0.769s) Loss 3.6442e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:08<00:00,  3.31s/it]
# Train 4: Time 6.461s (it:5.255s) Data:1.251s (it:1.172s) Loss 3.4385e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:08<00:00,  6.46s/it]
# Evaluate 4: Time 3.459s (it:2.478s) Data:0.926s (it:0.790s) Loss 3.4249e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:17<00:00,  3.46s/it]
# Train 5: Time 6.420s (it:6.886s) Data:1.205s (it:1.090s) Loss 3.3913e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:05<00:00,  6.42s/it]
# Evaluate 5: Time 3.501s (it:3.315s) Data:0.963s (it:0.760s) Loss 3.0868e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:19<00:00,  3.50s/it]
# Train 6: Time 6.499s (it:5.076s) Data:1.271s (it:1.079s) Loss 3.2664e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:10<00:00,  6.50s/it]
# Evaluate 6: Time 3.427s (it:3.923s) Data:0.910s (it:0.740s) Loss 3.1338e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:15<00:00,  3.43s/it]
# Train 7: Time 6.458s (it:5.148s) Data:1.237s (it:1.131s) Loss 3.3873e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:08<00:00,  6.46s/it]
# Evaluate 7: Time 3.502s (it:3.806s) Data:0.945s (it:0.791s) Loss 3.1467e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:19<00:00,  3.50s/it]
# Train 8: Time 6.502s (it:6.173s) Data:1.279s (it:1.123s) Loss 3.2784e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:10<00:00,  6.50s/it]
# Evaluate 8: Time 3.465s (it:2.486s) Data:0.918s (it:0.782s) Loss 2.9411e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:17<00:00,  3.47s/it]
# Train 9: Time 6.447s (it:6.691s) Data:1.236s (it:1.057s) Loss 3.2480e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:07<00:00,  6.45s/it]
# Evaluate 9: Time 3.201s (it:2.272s) Data:0.922s (it:0.708s) Loss 3.0869e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:02<00:00,  3.20s/it]
# Train 10: Time 5.929s (it:6.652s) Data:1.176s (it:1.082s) Loss 3.2323e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:37<00:00,  5.93s/it]
# Evaluate 10: Time 3.170s (it:4.011s) Data:0.970s (it:0.787s) Loss 3.0574e+00 : 100%|████████████████████████████████████████████| 57/57 [03:00<00:00,  3.17s/it]
# Train 11: Time 6.598s (it:6.050s) Data:1.268s (it:1.048s) Loss 3.2853e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:16<00:00,  6.60s/it]
# Evaluate 11: Time 3.527s (it:2.739s) Data:0.921s (it:0.765s) Loss 3.1167e+00 : 100%|████████████████████████████████████████████| 57/57 [03:21<00:00,  3.53s/it]
# Train 12: Time 6.621s (it:6.420s) Data:1.261s (it:1.124s) Loss 3.2246e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:17<00:00,  6.62s/it]
# Evaluate 12: Time 3.444s (it:3.291s) Data:0.978s (it:0.715s) Loss 3.0167e+00 : 100%|████████████████████████████████████████████| 57/57 [03:16<00:00,  3.44s/it]
# Train 13: Time 6.684s (it:5.050s) Data:1.260s (it:1.120s) Loss 3.3135e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:20<00:00,  6.68s/it]
# Evaluate 13: Time 3.726s (it:2.595s) Data:0.956s (it:0.835s) Loss 3.0148e+00 : 100%|████████████████████████████████████████████| 57/57 [03:32<00:00,  3.73s/it]
# Train 14: Time 6.552s (it:5.141s) Data:1.295s (it:1.078s) Loss 3.3176e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:13<00:00,  6.55s/it]
# Evaluate 14: Time 3.402s (it:2.640s) Data:0.950s (it:0.755s) Loss 3.1319e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.40s/it]
# Train 15: Time 6.807s (it:6.312s) Data:1.344s (it:1.181s) Loss 3.2740e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:28<00:00,  6.81s/it]
# Evaluate 15: Time 3.621s (it:2.697s) Data:0.928s (it:0.741s) Loss 3.1510e+00 : 100%|████████████████████████████████████████████| 57/57 [03:26<00:00,  3.62s/it]
# Train 16: Time 6.612s (it:5.237s) Data:1.288s (it:1.049s) Loss 3.2563e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:16<00:00,  6.61s/it]
# Evaluate 16: Time 3.223s (it:3.334s) Data:0.943s (it:0.753s) Loss 3.0355e+00 : 100%|████████████████████████████████████████████| 57/57 [03:03<00:00,  3.22s/it]
# Train 17: Time 6.301s (it:6.543s) Data:1.213s (it:1.045s) Loss 3.2360e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:59<00:00,  6.30s/it]
# Evaluate 17: Time 3.490s (it:2.675s) Data:0.950s (it:0.727s) Loss 2.9714e+00 : 100%|████████████████████████████████████████████| 57/57 [03:18<00:00,  3.49s/it]
# Train 18: Time 6.341s (it:5.069s) Data:1.219s (it:1.132s) Loss 3.2310e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:01<00:00,  6.34s/it]
# Evaluate 18: Time 3.300s (it:3.405s) Data:0.909s (it:0.709s) Loss 3.0643e+00 : 100%|████████████████████████████████████████████| 57/57 [03:08<00:00,  3.30s/it]
# Train 19: Time 6.356s (it:6.956s) Data:1.220s (it:1.113s) Loss 3.2997e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:02<00:00,  6.36s/it]
# Evaluate 19: Time 3.348s (it:2.535s) Data:0.936s (it:0.716s) Loss 2.9923e+00 : 100%|████████████████████████████████████████████| 57/57 [03:10<00:00,  3.35s/it]
# Train 20: Time 6.359s (it:5.086s) Data:1.224s (it:1.064s) Loss 3.2431e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:02<00:00,  6.36s/it]
# Evaluate 20: Time 3.347s (it:2.729s) Data:0.984s (it:0.788s) Loss 3.0854e+00 : 100%|████████████████████████████████████████████| 57/57 [03:10<00:00,  3.35s/it]
# Train 21: Time 6.334s (it:6.693s) Data:1.270s (it:1.031s) Loss 3.3077e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:01<00:00,  6.33s/it]
# Evaluate 21: Time 3.432s (it:2.550s) Data:0.909s (it:0.745s) Loss 3.1277e+00 : 100%|████████████████████████████████████████████| 57/57 [03:15<00:00,  3.43s/it]
# Train 22: Time 6.260s (it:5.101s) Data:1.205s (it:1.070s) Loss 3.2885e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:56<00:00,  6.26s/it]
# Evaluate 22: Time 3.379s (it:4.165s) Data:0.934s (it:0.728s) Loss 3.0351e+00 : 100%|████████████████████████████████████████████| 57/57 [03:12<00:00,  3.38s/it]
# Train 23: Time 6.443s (it:5.169s) Data:1.310s (it:1.120s) Loss 3.2270e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:07<00:00,  6.44s/it]
# Evaluate 23: Time 3.421s (it:2.709s) Data:0.896s (it:0.787s) Loss 3.1101e+00 : 100%|████████████████████████████████████████████| 57/57 [03:14<00:00,  3.42s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
#  Ball Recovery
# Data preprocessing: 100%|██████████| 10/10 [02:57<00:00, 17.72s/it]
# Get labels & features: 100%|██████████| 40/40 [12:05<00:00, 18.14s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 2/2 [00:36<00:00, 18.31s/it]
# Get labels & features: 100%|██████████| 8/8 [02:11<00:00, 16.39s/it]
# Train 1: Time 6.119s (it:5.296s) Data:1.138s (it:1.136s) Loss 4.6300e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:48<00:00,  6.12s/it]
# Evaluate 1: Time 3.190s (it:2.862s) Data:0.876s (it:0.702s) Loss 7.8628e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:01<00:00,  3.19s/it]
# Train 2: Time 6.206s (it:6.018s) Data:1.147s (it:1.090s) Loss 4.4427e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:53<00:00,  6.21s/it]
# Evaluate 2: Time 3.310s (it:3.925s) Data:0.953s (it:0.736s) Loss 6.4853e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:08<00:00,  3.31s/it]
# Train 3: Time 6.213s (it:5.038s) Data:1.189s (it:1.044s) Loss 4.5377e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:54<00:00,  6.21s/it]
# Evaluate 3: Time 3.304s (it:2.657s) Data:0.908s (it:0.737s) Loss 4.8755e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:08<00:00,  3.30s/it]
# Train 4: Time 6.180s (it:5.009s) Data:1.181s (it:1.094s) Loss 4.3941e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:52<00:00,  6.18s/it]
# Evaluate 4: Time 3.491s (it:5.587s) Data:1.015s (it:2.493s) Loss 4.5339e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:19<00:00,  3.49s/it]
# Train 5: Time 6.257s (it:6.525s) Data:1.196s (it:1.076s) Loss 4.4085e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:56<00:00,  6.26s/it]
# Evaluate 5: Time 3.281s (it:2.624s) Data:0.908s (it:0.730s) Loss 4.5103e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:06<00:00,  3.28s/it]
# Train 6: Time 6.168s (it:5.962s) Data:1.200s (it:1.031s) Loss 4.4682e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:51<00:00,  6.17s/it]
# Evaluate 6: Time 3.536s (it:2.543s) Data:0.931s (it:0.801s) Loss 4.3093e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:21<00:00,  3.54s/it]
# Train 7: Time 6.384s (it:7.038s) Data:1.208s (it:1.089s) Loss 4.4572e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:03<00:00,  6.38s/it]
# Evaluate 7: Time 3.501s (it:4.159s) Data:0.980s (it:0.862s) Loss 4.3299e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:19<00:00,  3.50s/it]
# Train 8: Time 6.313s (it:5.201s) Data:1.234s (it:1.117s) Loss 4.4647e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:59<00:00,  6.31s/it]
# Evaluate 8: Time 3.466s (it:2.589s) Data:0.949s (it:0.826s) Loss 4.2650e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:17<00:00,  3.47s/it]
# Train 9: Time 6.560s (it:5.195s) Data:1.260s (it:1.126s) Loss 4.4113e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:13<00:00,  6.56s/it]
# Evaluate 9: Time 3.663s (it:3.507s) Data:0.979s (it:0.746s) Loss 4.3816e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:28<00:00,  3.66s/it]
# Train 10: Time 6.844s (it:6.712s) Data:1.309s (it:1.151s) Loss 4.4737e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:30<00:00,  6.84s/it]
# Evaluate 10: Time 3.735s (it:2.479s) Data:0.942s (it:0.770s) Loss 4.2392e+00 : 100%|████████████████████████████████████████████| 57/57 [03:32<00:00,  3.73s/it]
# Train 11: Time 6.637s (it:7.172s) Data:1.283s (it:1.304s) Loss 4.5279e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:18<00:00,  6.64s/it]
# Evaluate 11: Time 4.296s (it:4.396s) Data:1.017s (it:0.875s) Loss 4.4160e+00 : 100%|████████████████████████████████████████████| 57/57 [04:04<00:00,  4.30s/it]
# Train 12: Time 7.350s (it:7.035s) Data:1.317s (it:1.197s) Loss 4.4014e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:58<00:00,  7.35s/it]
# Evaluate 12: Time 3.690s (it:2.485s) Data:0.983s (it:0.787s) Loss 4.5420e+00 : 100%|████████████████████████████████████████████| 57/57 [03:30<00:00,  3.69s/it]
# Train 13: Time 6.674s (it:6.798s) Data:1.326s (it:1.154s) Loss 4.4185e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:20<00:00,  6.67s/it]
# Evaluate 13: Time 3.217s (it:2.695s) Data:0.925s (it:0.751s) Loss 4.3388e+00 : 100%|████████████████████████████████████████████| 57/57 [03:03<00:00,  3.22s/it]
# Train 14: Time 6.904s (it:7.275s) Data:1.293s (it:1.270s) Loss 4.3740e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:33<00:00,  6.90s/it]
# Evaluate 14: Time 3.874s (it:3.725s) Data:0.979s (it:0.705s) Loss 4.2072e+00 : 100%|████████████████████████████████████████████| 57/57 [03:40<00:00,  3.87s/it]
# Train 15: Time 5.910s (it:8.563s) Data:1.196s (it:2.953s) Loss 4.4153e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:36<00:00,  5.91s/it]
# Evaluate 15: Time 2.996s (it:2.553s) Data:0.907s (it:0.709s) Loss 4.3226e+00 : 100%|████████████████████████████████████████████| 57/57 [02:50<00:00,  3.00s/it]
# Train 16: Time 6.009s (it:5.126s) Data:1.172s (it:1.076s) Loss 4.3441e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:42<00:00,  6.01s/it]
# Evaluate 16: Time 3.089s (it:2.407s) Data:0.899s (it:0.737s) Loss 4.2981e+00 : 100%|████████████████████████████████████████████| 57/57 [02:56<00:00,  3.09s/it]
# Train 17: Time 6.064s (it:5.323s) Data:1.178s (it:1.018s) Loss 4.3738e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:45<00:00,  6.06s/it]
# Evaluate 17: Time 3.110s (it:3.685s) Data:0.932s (it:0.734s) Loss 4.1890e+00 : 100%|████████████████████████████████████████████| 57/57 [02:57<00:00,  3.11s/it]
# Train 18: Time 6.074s (it:6.804s) Data:1.157s (it:1.122s) Loss 4.5140e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:46<00:00,  6.07s/it]
# Evaluate 18: Time 3.078s (it:2.394s) Data:0.900s (it:0.719s) Loss 4.4388e+00 : 100%|████████████████████████████████████████████| 57/57 [02:55<00:00,  3.08s/it]
# Train 19: Time 6.012s (it:6.748s) Data:1.147s (it:1.023s) Loss 4.4728e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:42<00:00,  6.01s/it]
# Evaluate 19: Time 3.081s (it:2.549s) Data:0.935s (it:0.695s) Loss 4.2564e+00 : 100%|████████████████████████████████████████████| 57/57 [02:55<00:00,  3.08s/it]
# Train 20: Time 6.034s (it:5.239s) Data:1.211s (it:1.035s) Loss 4.4440e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:43<00:00,  6.03s/it]
# Evaluate 20: Time 3.126s (it:2.457s) Data:0.891s (it:0.697s) Loss 4.3445e+00 : 100%|████████████████████████████████████████████| 57/57 [02:58<00:00,  3.13s/it]
# Train 21: Time 6.041s (it:5.033s) Data:1.174s (it:1.052s) Loss 4.4302e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:44<00:00,  6.04s/it]
# Evaluate 21: Time 3.399s (it:2.888s) Data:0.948s (it:0.794s) Loss 4.3002e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.40s/it]
# Train 22: Time 6.325s (it:5.156s) Data:1.260s (it:1.093s) Loss 4.3956e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:00<00:00,  6.33s/it]
# Evaluate 22: Time 3.133s (it:2.464s) Data:0.940s (it:0.735s) Loss 4.3687e+00 : 100%|████████████████████████████████████████████| 57/57 [02:58<00:00,  3.13s/it]
# Train 23: Time 6.278s (it:4.976s) Data:1.192s (it:1.036s) Loss 4.4816e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:57<00:00,  6.28s/it]
# Evaluate 23: Time 3.143s (it:2.436s) Data:0.937s (it:0.709s) Loss 4.2989e+00 : 100%|████████████████████████████████████████████| 57/57 [02:59<00:00,  3.14s/it]
# Train 24: Time 6.194s (it:6.852s) Data:1.236s (it:1.045s) Loss 4.4087e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:53<00:00,  6.19s/it]
# Evaluate 24: Time 3.081s (it:3.634s) Data:0.900s (it:0.707s) Loss 4.4333e+00 : 100%|████████████████████████████████████████████| 57/57 [02:55<00:00,  3.08s/it]
# Train 25: Time 6.091s (it:5.448s) Data:1.225s (it:1.092s) Loss 4.4552e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:47<00:00,  6.09s/it]
# Evaluate 25: Time 3.034s (it:2.468s) Data:0.894s (it:0.722s) Loss 4.3598e+00 : 100%|████████████████████████████████████████████| 57/57 [02:52<00:00,  3.03s/it]
# Train 26: Time 6.007s (it:5.366s) Data:1.180s (it:1.065s) Loss 4.4360e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:42<00:00,  6.01s/it]
# Evaluate 26: Time 3.074s (it:2.744s) Data:0.908s (it:0.763s) Loss 4.3517e+00 : 100%|████████████████████████████████████████████| 57/57 [02:55<00:00,  3.07s/it]
# Train 27: Time 6.112s (it:5.246s) Data:1.174s (it:1.078s) Loss 4.3918e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:48<00:00,  6.11s/it]
# Evaluate 27: Time 3.246s (it:2.633s) Data:0.953s (it:0.717s) Loss 4.3742e+00 : 100%|████████████████████████████████████████████| 57/57 [03:04<00:00,  3.25s/it]
# Train 28: Time 6.014s (it:5.051s) Data:1.198s (it:1.063s) Loss 4.3863e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:42<00:00,  6.01s/it]
# Evaluate 28: Time 3.136s (it:3.578s) Data:0.909s (it:0.719s) Loss 4.3655e+00 : 100%|████████████████████████████████████████████| 57/57 [02:58<00:00,  3.14s/it]
# Train 29: Time 6.077s (it:5.331s) Data:1.197s (it:1.047s) Loss 4.4073e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:46<00:00,  6.08s/it]
# Evaluate 29: Time 3.151s (it:2.628s) Data:0.910s (it:0.731s) Loss 4.2412e+00 : 100%|████████████████████████████████████████████| 57/57 [02:59<00:00,  3.15s/it]
# Train 30: Time 6.195s (it:10.318s) Data:1.255s (it:4.543s) Loss 4.2943e+00 : 100%|██████████████████████████████████████████████| 57/57 [05:53<00:00,  6.20s/it]
# Evaluate 30: Time 3.133s (it:2.655s) Data:0.908s (it:0.729s) Loss 4.2923e+00 : 100%|████████████████████████████████████████████| 57/57 [02:58<00:00,  3.13s/it]
# Train 31: Time 6.111s (it:6.545s) Data:1.203s (it:1.055s) Loss 4.3739e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:48<00:00,  6.11s/it]
# Evaluate 31: Time 3.154s (it:2.697s) Data:0.911s (it:0.766s) Loss 4.3180e+00 : 100%|████████████████████████████████████████████| 57/57 [02:59<00:00,  3.15s/it]
# Train 32: Time 6.196s (it:5.248s) Data:1.221s (it:1.071s) Loss 4.3947e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:53<00:00,  6.20s/it]
# Evaluate 32: Time 3.173s (it:5.652s) Data:0.955s (it:2.459s) Loss 4.2509e+00 : 100%|████████████████████████████████████████████| 57/57 [03:00<00:00,  3.17s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
#  Duel
# Data preprocessing: 100%|██████████| 10/10 [02:55<00:00, 17.58s/it]
# Get labels & features: 100%|██████████| 40/40 [12:05<00:00, 18.14s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# ...
# Train 20: Time 34.619s (it:6.859s) Data:1.250s (it:1.300s) Loss 2.3530e+00 : 100%|██████████████████████████████████████████████| 57/57 [32:53<00:00, 34.62s/it]
# Evaluate 20: Time 3.547s (it:3.866s) Data:0.975s (it:0.730s) Loss 2.0233e+00 : 100%|████████████████████████████████████████████| 57/57 [03:22<00:00,  3.55s/it]
# Train 21: Time 6.388s (it:6.012s) Data:1.282s (it:1.015s) Loss 2.3996e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:04<00:00,  6.39s/it]
# Evaluate 21: Time 3.274s (it:2.721s) Data:0.885s (it:0.803s) Loss 2.0315e+00 : 100%|████████████████████████████████████████████| 57/57 [03:06<00:00,  3.27s/it]
# Train 22: Time 6.212s (it:5.285s) Data:1.226s (it:1.054s) Loss 2.3576e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:54<00:00,  6.21s/it]
# Evaluate 22: Time 3.246s (it:2.375s) Data:0.893s (it:0.702s) Loss 2.0847e+00 : 100%|████████████████████████████████████████████| 57/57 [03:05<00:00,  3.25s/it]
# Train 23: Time 6.073s (it:5.307s) Data:1.181s (it:1.086s) Loss 2.3425e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:46<00:00,  6.07s/it]
# Evaluate 23: Time 3.283s (it:5.691s) Data:0.935s (it:2.551s) Loss 2.0267e+00 : 100%|████████████████████████████████████████████| 57/57 [03:07<00:00,  3.28s/it]
# Train 24: Time 6.161s (it:5.062s) Data:1.199s (it:1.072s) Loss 2.2966e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:51<00:00,  6.16s/it]
# Evaluate 24: Time 3.249s (it:2.496s) Data:0.889s (it:0.793s) Loss 2.0487e+00 : 100%|████████████████████████████████████████████| 57/57 [03:05<00:00,  3.25s/it]
# Train 25: Time 6.258s (it:5.101s) Data:1.187s (it:1.081s) Loss 2.3328e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:56<00:00,  6.26s/it]
# Evaluate 25: Time 3.403s (it:2.762s) Data:0.939s (it:0.780s) Loss 2.1243e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.40s/it]
# Train 26: Time 6.977s (it:6.275s) Data:1.352s (it:1.110s) Loss 2.3305e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:37<00:00,  6.98s/it]
# Evaluate 26: Time 3.627s (it:2.695s) Data:0.929s (it:0.779s) Loss 2.2611e+00 : 100%|████████████████████████████████████████████| 57/57 [03:26<00:00,  3.63s/it]
# Train 27: Time 6.406s (it:5.248s) Data:1.253s (it:1.024s) Loss 2.3161e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:05<00:00,  6.41s/it]
# Evaluate 27: Time 3.304s (it:3.760s) Data:0.910s (it:0.729s) Loss 2.0718e+00 : 100%|████████████████████████████████████████████| 57/57 [03:08<00:00,  3.30s/it]
# Train 28: Time 6.402s (it:11.131s) Data:1.279s (it:5.189s) Loss 2.2628e+00 : 100%|██████████████████████████████████████████████| 57/57 [06:04<00:00,  6.40s/it]
# Evaluate 28: Time 3.259s (it:2.445s) Data:0.878s (it:0.710s) Loss 2.0036e+00 : 100%|████████████████████████████████████████████| 57/57 [03:05<00:00,  3.26s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
#  Dribble
# Data preprocessing: 100%|██████████| 10/10 [02:56<00:00, 17.68s/it]
# Get labels & features: 100%|██████████| 40/40 [12:05<00:00, 18.14s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 2/2 [00:36<00:00, 18.43s/it]
# Get labels & features: 100%|██████████| 8/8 [02:09<00:00, 16.19s/it]
# Train 1: Time 6.183s (it:4.991s) Data:1.121s (it:1.016s) Loss 4.0272e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:52<00:00,  6.18s/it]
# Evaluate 1: Time 3.250s (it:2.637s) Data:0.865s (it:0.709s) Loss 6.0658e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:05<00:00,  3.25s/it]
# Train 2: Time 6.085s (it:9.922s) Data:1.167s (it:4.020s) Loss 3.6597e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:46<00:00,  6.09s/it]
# Evaluate 2: Time 4.732s (it:4.005s) Data:1.126s (it:0.864s) Loss 4.8675e+00 : 100%|█████████████████████████████████████████████| 57/57 [04:29<00:00,  4.73s/it]
# Train 3: Time 7.636s (it:7.648s) Data:1.388s (it:1.191s) Loss 3.6502e+00 : 100%|████████████████████████████████████████████████| 57/57 [07:15<00:00,  7.64s/it]
# Evaluate 3: Time 5.007s (it:4.342s) Data:1.180s (it:0.853s) Loss 4.2380e+00 : 100%|█████████████████████████████████████████████| 57/57 [04:45<00:00,  5.01s/it]
# Train 4: Time 8.165s (it:7.142s) Data:1.588s (it:1.290s) Loss 3.6080e+00 : 100%|████████████████████████████████████████████████| 57/57 [07:45<00:00,  8.17s/it]
# Evaluate 4: Time 4.473s (it:7.856s) Data:1.187s (it:4.077s) Loss 3.8593e+00 : 100%|█████████████████████████████████████████████| 57/57 [04:14<00:00,  4.47s/it]
# Train 5: Time 7.611s (it:5.770s) Data:1.536s (it:1.277s) Loss 3.5570e+00 : 100%|████████████████████████████████████████████████| 57/57 [07:13<00:00,  7.61s/it]
# Evaluate 5: Time 4.367s (it:2.871s) Data:1.115s (it:0.830s) Loss 4.0150e+00 : 100%|█████████████████████████████████████████████| 57/57 [04:08<00:00,  4.37s/it]
# Train 6: Time 7.721s (it:8.127s) Data:1.530s (it:1.240s) Loss 3.5554e+00 : 100%|████████████████████████████████████████████████| 57/57 [07:20<00:00,  7.72s/it]
# Evaluate 6: Time 4.600s (it:4.375s) Data:1.151s (it:0.862s) Loss 4.0050e+00 : 100%|█████████████████████████████████████████████| 57/57 [04:22<00:00,  4.60s/it]
# Train 7: Time 7.663s (it:7.210s) Data:1.559s (it:1.403s) Loss 3.5386e+00 : 100%|████████████████████████████████████████████████| 57/57 [07:16<00:00,  7.66s/it]
# Evaluate 7: Time 4.771s (it:4.587s) Data:1.341s (it:0.822s) Loss 3.8266e+00 : 100%|█████████████████████████████████████████████| 57/57 [04:31<00:00,  4.77s/it]
# Train 8: Time 7.952s (it:8.259s) Data:1.612s (it:1.331s) Loss 3.5360e+00 : 100%|████████████████████████████████████████████████| 57/57 [07:33<00:00,  7.95s/it]
# Evaluate 8: Time 4.811s (it:2.960s) Data:1.142s (it:0.924s) Loss 3.9622e+00 : 100%|█████████████████████████████████████████████| 57/57 [04:34<00:00,  4.81s/it]
# Train 9: Time 7.878s (it:5.986s) Data:1.592s (it:1.310s) Loss 3.4943e+00 : 100%|████████████████████████████████████████████████| 57/57 [07:29<00:00,  7.88s/it]
# Evaluate 9: Time 4.172s (it:3.257s) Data:1.113s (it:0.895s) Loss 3.9652e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:57<00:00,  4.17s/it]
# Train 10: Time 7.781s (it:8.019s) Data:1.623s (it:1.580s) Loss 3.5347e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:23<00:00,  7.78s/it]
# Evaluate 10: Time 4.520s (it:4.647s) Data:1.311s (it:1.498s) Loss 3.9813e+00 : 100%|████████████████████████████████████████████| 57/57 [04:17<00:00,  4.52s/it]
# Train 11: Time 7.760s (it:6.968s) Data:1.607s (it:1.239s) Loss 3.5225e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:22<00:00,  7.76s/it]
# Evaluate 11: Time 4.421s (it:4.148s) Data:1.182s (it:0.853s) Loss 3.9008e+00 : 100%|████████████████████████████████████████████| 57/57 [04:11<00:00,  4.42s/it]
# Train 12: Time 7.312s (it:7.151s) Data:1.457s (it:1.341s) Loss 3.5402e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:56<00:00,  7.31s/it]
# Evaluate 12: Time 3.990s (it:3.772s) Data:1.120s (it:0.778s) Loss 3.7704e+00 : 100%|████████████████████████████████████████████| 57/57 [03:47<00:00,  3.99s/it]
# Train 13: Time 7.282s (it:8.263s) Data:1.491s (it:1.507s) Loss 3.4912e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:55<00:00,  7.28s/it]
# Evaluate 13: Time 4.834s (it:5.429s) Data:1.246s (it:0.926s) Loss 3.9604e+00 : 100%|████████████████████████████████████████████| 57/57 [04:35<00:00,  4.83s/it]
# Train 14: Time 7.810s (it:9.394s) Data:1.589s (it:1.610s) Loss 3.4901e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:25<00:00,  7.81s/it]
# Evaluate 14: Time 4.431s (it:3.811s) Data:1.215s (it:0.839s) Loss 3.9346e+00 : 100%|████████████████████████████████████████████| 57/57 [04:12<00:00,  4.43s/it]
# Train 15: Time 8.270s (it:5.618s) Data:1.560s (it:1.216s) Loss 3.4915e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:51<00:00,  8.27s/it]
# Evaluate 15: Time 4.222s (it:4.397s) Data:1.176s (it:0.883s) Loss 3.8697e+00 : 100%|████████████████████████████████████████████| 57/57 [04:00<00:00,  4.22s/it]
# Train 16: Time 7.826s (it:6.271s) Data:1.593s (it:1.915s) Loss 3.4358e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:26<00:00,  7.83s/it]
# Evaluate 16: Time 3.617s (it:4.061s) Data:0.973s (it:0.796s) Loss 3.9428e+00 : 100%|████████████████████████████████████████████| 57/57 [03:26<00:00,  3.62s/it]
# Train 17: Time 8.423s (it:8.048s) Data:1.619s (it:1.433s) Loss 3.4406e+00 : 100%|███████████████████████████████████████████████| 57/57 [08:00<00:00,  8.42s/it]
# Evaluate 17: Time 5.059s (it:5.040s) Data:1.252s (it:0.820s) Loss 3.9565e+00 : 100%|████████████████████████████████████████████| 57/57 [04:48<00:00,  5.06s/it]
# Train 18: Time 8.445s (it:7.516s) Data:1.659s (it:1.439s) Loss 3.4602e+00 : 100%|███████████████████████████████████████████████| 57/57 [08:01<00:00,  8.44s/it]
# Evaluate 18: Time 4.246s (it:4.442s) Data:1.137s (it:0.811s) Loss 3.8595e+00 : 100%|████████████████████████████████████████████| 57/57 [04:02<00:00,  4.25s/it]
# Train 19: Time 7.910s (it:8.311s) Data:1.497s (it:1.415s) Loss 3.4118e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:30<00:00,  7.91s/it]
# Evaluate 19: Time 3.998s (it:4.137s) Data:1.036s (it:0.835s) Loss 4.0600e+00 : 100%|████████████████████████████████████████████| 57/57 [03:47<00:00,  4.00s/it]
# Train 20: Time 7.356s (it:7.594s) Data:1.456s (it:1.406s) Loss 3.4296e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:59<00:00,  7.36s/it]
# Evaluate 20: Time 4.729s (it:4.979s) Data:1.104s (it:0.983s) Loss 3.8714e+00 : 100%|████████████████████████████████████████████| 57/57 [04:29<00:00,  4.73s/it]
# Train 21: Time 7.818s (it:7.774s) Data:1.575s (it:1.353s) Loss 3.4421e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:25<00:00,  7.82s/it]
# Evaluate 21: Time 4.481s (it:5.012s) Data:1.100s (it:1.122s) Loss 3.8552e+00 : 100%|████████████████████████████████████████████| 57/57 [04:15<00:00,  4.48s/it]
# Train 22: Time 7.829s (it:7.917s) Data:1.571s (it:1.507s) Loss 3.4176e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:26<00:00,  7.83s/it]
# Evaluate 22: Time 4.749s (it:4.463s) Data:1.209s (it:0.907s) Loss 3.7930e+00 : 100%|████████████████████████████████████████████| 57/57 [04:30<00:00,  4.75s/it]
# Train 23: Time 7.592s (it:7.261s) Data:1.488s (it:1.321s) Loss 3.5216e+00 : 100%|███████████████████████████████████████████████| 57/57 [07:12<00:00,  7.59s/it]
# Evaluate 23: Time 4.905s (it:4.926s) Data:1.243s (it:0.912s) Loss 3.8516e+00 : 100%|████████████████████████████████████████████| 57/57 [04:39<00:00,  4.90s/it]
# Train 24: Time 7.714s (it:7.230s) Data:1.574s (it:1.354s) Loss 3.3903e+00 :  98%|██████████████████████████████████████████████▏| 56/57 [07:11<00:07,  7.48s/it]

# %%
args = Args

precisions_combined = np.empty(0)
recalls_combined = np.empty(0)
f1_combined = np.empty(0)

prediction_x_data = []
prediction_y_data = []

annotation_x_data = []
annotation_y_data = []

for i, ann in enumerate(event_enc.keys()):

    args.focused_annotation = ann

    collate_fn = collateVisGCN
    model_path = f"models/finetuned_{ann}.pth.tar"
    model = torch.load(model_path)

    visualiser = Visualiser(collate_fn, args, model, smooth_rate=None, val=True, ann=ann)
    fig, ax = visualiser.plot_predictions(frame_threshold=20000, save_dir=None, annotation=ann)
    
    prediction_x_data.append(ax.get_lines()[0].get_xdata()) 
    prediction_y_data.append(ax.get_lines()[0].get_ydata())

    annotation_x_data.append(ax.get_lines()[1].get_xdata()) 
    annotation_y_data.append(ax.get_lines()[1].get_ydata())

    precision, recall, f1_score, _ = visualiser.norm_evaluation_segmentation(ann)

    precisions_combined = np.concatenate((precisions_combined, precision), axis=0)
    recalls_combined = np.concatenate((recalls_combined, recall), axis=0)
    f1_combined = np.concatenate((f1_combined, f1_score), axis=0)


precisions_combined = np.concatenate((np.array([np.mean(precisions_combined)]), precisions_combined), axis=0)
recalls_combined = np.concatenate((np.array([np.mean(recalls_combined)]), recalls_combined), axis=0)
f1_combined = np.concatenate((np.array([np.mean(f1_combined)]), f1_combined), axis=0)
# Out:
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.51s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.43s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.44s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.53s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.66s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.47s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.50s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.47s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.46s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.42s/it]

# %%
cols = ["Total"] + list(event_enc.keys())
rows = ["Precision", "Recall", "F1-score"]

fig = plt.figure(figsize=(20, 2))

total_scores = np.concatenate((precisions_combined, recalls_combined, f1_combined))

# ax1.set_title("Precision scores")
ax = sns.heatmap(total_scores.reshape(3,-1), annot=True, cmap="coolwarm", fmt=".2f", xticklabels=True, yticklabels=True)
ax.set_xticklabels(cols, rotation=0)
ax.xaxis.tick_top()
ax.set_yticklabels(rows, rotation=0)

plt.title("Evaluation of fine-tuned models")
plt.show()

# %%
cols = ["Total"] + list(event_enc.keys())
rows = ["Precision", "Recall", "F1-score"]

fig = plt.figure(figsize=(20, 2))

total_scores = np.concatenate((precisions_combined, recalls_combined, f1_combined))

# ax1.set_title("Precision scores")
ax = sns.heatmap(total_scores.reshape(3,-1), annot=True, cmap="coolwarm", fmt=".2f", xticklabels=True, yticklabels=True)
ax.set_xticklabels(cols, rotation=0)
ax.xaxis.tick_top()
ax.set_yticklabels(rows, rotation=0)

plt.title("Evaluation of fine-tuned models")
plt.show()

# %%
fig, axes = plt.subplots(5, 2, figsize=(20, 20))
axes_flattened = axes.flatten()

for i, ax in enumerate(axes_flattened):
    ax.plot(prediction_x_data[i], prediction_y_data[i], label="Predictions")
    ax.plot(annotation_x_data[i], annotation_y_data[i], label="Annotations")
    ax.set_title(list(event_enc)[i])

plt.legend()
plt.show()
