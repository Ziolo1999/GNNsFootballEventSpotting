# %%
import os
os.chdir("../")
from data_management.DataManager import CALFData, collateGCN
import numpy as np
import torch 
from Model import ContextAwareModel
from helpers.loss import ContextAwareLoss, SpottingLoss
from modules.train import trainer
import pickle
from dataclasses import dataclass
import matplotlib.pyplot as plt
from modules.GameAnalysis import GamaAnalysis
import seaborn as sns
from helpers.classes import EVENT_DICTIONARY_V2_ALIVE as event_enc
from helpers.classes import get_K_params
import torch.nn as nn

# %%
@dataclass
class Args:
    receptive_field = 12
    fps = 5
    chunks_per_epoch = 1824
    class_split = "alive"
    chunk_size = 60
    batch_size = 32
    input_channel = 13
    feature_multiplier=1
    backbone_player = "GCN"
    max_epochs=180
    load_weights=None
    model_name="Testing_Model"
    dim_capsule=16
    lambda_coord=5.0
    lambda_noobj=0.5
    patience=25
    LR=1e-03
    GPU=0 
    max_num_worker=1
    loglevel='INFO'
    annotation_nr = 1
    K_parameters = get_K_params(chunk_size)
    focused_annotation = "Duel"
    generate_augmented_data = True
    sgementation_path = "models/gridsearch5.pth.tar"
    freeze_model = True
    generate_artificial_targets = False

# %%
args = Args
collate_fn = collateGCN
list_anns = list(event_enc.keys())[6:]

for ann in list_anns:
    print(f"\n {ann}")
    args.focused_annotation = ann
    
    # Read data for specific annotation
    train_dataset = CALFData(split="train", args=args)
    validation_dataset = CALFData(split="validate", args=args)

    train_loader = torch.utils.data.DataLoader(train_dataset,
                batch_size=args.batch_size, shuffle=True, collate_fn=collate_fn)

    validate_loader = torch.utils.data.DataLoader(validation_dataset,
                batch_size=args.batch_size, shuffle=True, collate_fn=collate_fn)

    # Load pre-trained model and adjust it
    model = torch.load(args.sgementation_path)
    model.num_classes = 1
    model.conv_seg = nn.Conv2d(in_channels=152, out_channels=model.dim_capsule, kernel_size=(model.kernel_seg_size,1))
    
    criterion = ContextAwareLoss(K=train_dataset.K_parameters)
    optimizer = torch.optim.Adam(model.parameters(), lr=args.LR, 
                                betas=(0.9, 0.999), eps=1e-07, 
                                weight_decay=0, amsgrad=False)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', verbose=True, patience=args.patience)

    losses = trainer(train_loader, validate_loader,
                        model, optimizer, scheduler, 
                        criterion,
                        model_name=args.model_name,
                        max_epochs=args.max_epochs, 
                        save_dir=f"models/finetuned_{ann}.pth.tar")

    with open(f'results/finetuned_{ann}.pkl', 'wb') as file:
        pickle.dump(losses, file)
    
    del train_dataset,validation_dataset,train_loader, validate_loader,model
# Out:
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
#  Clearance
# Data preprocessing: 100%|██████████| 10/10 [03:08<00:00, 18.80s/it]
# Get labels & features: 100%|██████████| 40/40 [12:42<00:00, 19.06s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 2/2 [00:39<00:00, 19.72s/it]
# Get labels & features: 100%|██████████| 8/8 [02:11<00:00, 16.42s/it]
# Train 1: Time 6.513s (it:5.236s) Data:1.338s (it:1.103s) Loss 3.3091e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:11<00:00,  6.51s/it]
# Evaluate 1: Time 3.399s (it:2.854s) Data:1.006s (it:0.848s) Loss 5.7750e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:13<00:00,  3.40s/it]
# Train 2: Time 6.538s (it:5.493s) Data:1.312s (it:1.137s) Loss 3.1462e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:12<00:00,  6.54s/it]
# Evaluate 2: Time 3.657s (it:4.106s) Data:1.030s (it:0.831s) Loss 4.6787e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:28<00:00,  3.66s/it]
# Train 3: Time 6.952s (it:6.902s) Data:1.437s (it:1.211s) Loss 3.0325e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:36<00:00,  6.95s/it]
# Evaluate 3: Time 3.811s (it:2.596s) Data:1.074s (it:0.866s) Loss 3.8304e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:37<00:00,  3.81s/it]
# Train 4: Time 6.760s (it:6.746s) Data:1.351s (it:1.169s) Loss 3.0423e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:25<00:00,  6.76s/it]
# Evaluate 4: Time 3.443s (it:4.111s) Data:0.957s (it:0.856s) Loss 3.4567e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:16<00:00,  3.44s/it]
# Train 5: Time 6.667s (it:6.919s) Data:1.323s (it:1.161s) Loss 2.9982e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:20<00:00,  6.67s/it]
# Evaluate 5: Time 3.581s (it:2.752s) Data:1.060s (it:0.813s) Loss 3.1223e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:24<00:00,  3.58s/it]
# Train 6: Time 6.671s (it:7.567s) Data:1.323s (it:1.251s) Loss 3.0531e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:20<00:00,  6.67s/it]
# Evaluate 6: Time 3.537s (it:2.687s) Data:1.055s (it:0.789s) Loss 3.3118e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:21<00:00,  3.54s/it]
# Train 7: Time 6.746s (it:5.388s) Data:1.361s (it:1.084s) Loss 3.0205e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:24<00:00,  6.75s/it]
# Evaluate 7: Time 3.705s (it:3.936s) Data:1.040s (it:0.877s) Loss 3.1330e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:31<00:00,  3.70s/it]
# Train 8: Time 7.124s (it:7.356s) Data:1.522s (it:1.468s) Loss 2.9638e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:46<00:00,  7.12s/it]
# Evaluate 8: Time 3.712s (it:2.558s) Data:1.086s (it:0.818s) Loss 3.2245e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:31<00:00,  3.71s/it]
# Train 9: Time 6.684s (it:6.799s) Data:1.368s (it:1.173s) Loss 2.9855e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:20<00:00,  6.68s/it]
# Evaluate 9: Time 3.577s (it:2.735s) Data:0.983s (it:0.799s) Loss 3.0882e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:23<00:00,  3.58s/it]
# Train 10: Time 6.628s (it:5.483s) Data:1.315s (it:1.136s) Loss 3.0076e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:17<00:00,  6.63s/it]
# Evaluate 10: Time 3.696s (it:2.671s) Data:1.091s (it:0.811s) Loss 3.0478e+00 : 100%|████████████████████████████████████████████| 57/57 [03:30<00:00,  3.70s/it]
# Train 11: Time 6.643s (it:7.397s) Data:1.332s (it:1.163s) Loss 2.9113e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:18<00:00,  6.64s/it]
# Evaluate 11: Time 3.573s (it:4.158s) Data:1.055s (it:0.808s) Loss 3.0661e+00 : 100%|████████████████████████████████████████████| 57/57 [03:23<00:00,  3.57s/it]
# Train 12: Time 6.837s (it:5.520s) Data:1.386s (it:1.173s) Loss 2.9467e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:29<00:00,  6.84s/it]
# Evaluate 12: Time 3.542s (it:3.010s) Data:1.048s (it:0.776s) Loss 3.0693e+00 : 100%|████████████████████████████████████████████| 57/57 [03:21<00:00,  3.54s/it]
# Train 13: Time 6.658s (it:6.956s) Data:1.400s (it:1.164s) Loss 2.9198e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:19<00:00,  6.66s/it]
# Evaluate 13: Time 3.509s (it:3.222s) Data:0.975s (it:0.832s) Loss 3.0263e+00 : 100%|████████████████████████████████████████████| 57/57 [03:19<00:00,  3.51s/it]
# Evaluate 22: Time 3.331s (it:6.565s) Data:1.020s (it:3.247s) Loss 3.1055e+00 : 100%|████████████████████████████████████████████| 57/57 [03:09<00:00,  3.33s/it]
# Train 23: Time 6.344s (it:5.505s) Data:1.231s (it:1.168s) Loss 2.9045e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:01<00:00,  6.34s/it]
# Evaluate 23: Time 3.392s (it:3.566s) Data:1.075s (it:0.839s) Loss 3.0200e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.39s/it]
# Train 24: Time 6.428s (it:6.151s) Data:1.308s (it:1.035s) Loss 2.9190e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:06<00:00,  6.43s/it]
# Evaluate 24: Time 3.514s (it:2.581s) Data:1.028s (it:0.832s) Loss 3.1865e+00 : 100%|████████████████████████████████████████████| 57/57 [03:20<00:00,  3.51s/it]
# Train 25: Time 6.501s (it:5.136s) Data:1.357s (it:1.112s) Loss 2.9608e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:10<00:00,  6.50s/it]
# Evaluate 25: Time 3.337s (it:3.829s) Data:1.015s (it:0.806s) Loss 3.1747e+00 : 100%|████████████████████████████████████████████| 57/57 [03:10<00:00,  3.34s/it]
# Train 26: Time 6.375s (it:6.340s) Data:1.334s (it:1.153s) Loss 2.8877e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:03<00:00,  6.38s/it]
# Evaluate 26: Time 3.398s (it:2.569s) Data:1.033s (it:0.822s) Loss 3.0544e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.40s/it]
# Train 27: Time 6.492s (it:5.512s) Data:1.376s (it:1.277s) Loss 2.8770e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:10<00:00,  6.49s/it]
# Evaluate 27: Time 3.321s (it:6.351s) Data:0.989s (it:3.099s) Loss 3.0674e+00 : 100%|████████████████████████████████████████████| 57/57 [03:09<00:00,  3.32s/it]
# Train 28: Time 6.411s (it:6.762s) Data:1.262s (it:1.278s) Loss 2.9232e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:05<00:00,  6.41s/it]
# Evaluate 28: Time 3.398s (it:2.811s) Data:1.050s (it:0.799s) Loss 3.0813e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.40s/it]
# Train 29: Time 6.555s (it:6.680s) Data:1.320s (it:1.320s) Loss 2.8137e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:13<00:00,  6.55s/it]
# Evaluate 29: Time 3.516s (it:2.782s) Data:1.086s (it:0.818s) Loss 3.0651e+00 : 100%|████████████████████████████████████████████| 57/57 [03:20<00:00,  3.52s/it]
# Train 30: Time 6.605s (it:6.350s) Data:1.333s (it:1.165s) Loss 2.8397e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:16<00:00,  6.61s/it]
# Evaluate 30: Time 3.919s (it:2.772s) Data:1.130s (it:0.815s) Loss 3.0456e+00 : 100%|████████████████████████████████████████████| 57/57 [03:43<00:00,  3.92s/it]
# Train 31: Time 6.631s (it:5.397s) Data:1.381s (it:1.087s) Loss 2.8082e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:17<00:00,  6.63s/it]
# Evaluate 31: Time 3.443s (it:2.824s) Data:1.044s (it:0.787s) Loss 3.1203e+00 : 100%|████████████████████████████████████████████| 57/57 [03:16<00:00,  3.44s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
#  Goal Keeper
# Data preprocessing: 100%|██████████| 10/10 [03:00<00:00, 18.08s/it]
# Get labels & features: 100%|██████████| 40/40 [12:32<00:00, 18.80s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 2/2 [00:36<00:00, 18.44s/it]
# Get labels & features: 100%|██████████| 8/8 [02:12<00:00, 16.62s/it]
# Train 1: Time 6.219s (it:5.224s) Data:1.248s (it:1.078s) Loss 3.1403e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:54<00:00,  6.22s/it]
# Evaluate 1: Time 3.391s (it:3.747s) Data:0.993s (it:0.760s) Loss 7.1965e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:13<00:00,  3.39s/it]
# Train 2: Time 6.319s (it:4.982s) Data:1.276s (it:1.075s) Loss 2.8190e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:00<00:00,  6.32s/it]
# Evaluate 2: Time 3.408s (it:2.786s) Data:1.008s (it:0.833s) Loss 5.1517e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:14<00:00,  3.41s/it]
# Train 3: Time 6.318s (it:5.256s) Data:1.282s (it:1.171s) Loss 2.7424e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:00<00:00,  6.32s/it]
# Evaluate 3: Time 3.442s (it:2.812s) Data:1.011s (it:0.809s) Loss 4.2578e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:16<00:00,  3.44s/it]
# Train 4: Time 6.374s (it:5.080s) Data:1.292s (it:1.129s) Loss 2.6216e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:03<00:00,  6.37s/it]
# Evaluate 4: Time 3.200s (it:2.644s) Data:1.018s (it:0.777s) Loss 3.1876e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:02<00:00,  3.20s/it]
# Train 5: Time 6.280s (it:6.270s) Data:1.294s (it:1.079s) Loss 2.6483e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:57<00:00,  6.28s/it]
# Evaluate 5: Time 3.317s (it:2.823s) Data:1.002s (it:0.817s) Loss 2.8803e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:09<00:00,  3.32s/it]
# Train 6: Time 6.297s (it:12.250s) Data:1.325s (it:6.393s) Loss 2.6667e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:58<00:00,  6.30s/it]
# Evaluate 6: Time 3.217s (it:2.750s) Data:0.929s (it:0.833s) Loss 2.4080e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:03<00:00,  3.22s/it]
# Train 7: Time 6.261s (it:5.351s) Data:1.265s (it:1.144s) Loss 2.6695e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:56<00:00,  6.26s/it]
# Evaluate 7: Time 3.293s (it:3.974s) Data:1.021s (it:0.768s) Loss 2.3000e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:07<00:00,  3.29s/it]
# Train 8: Time 6.324s (it:6.628s) Data:1.289s (it:1.152s) Loss 2.5034e+00 : 100%|████████████████████████████████████████████████| 57/57 [06:00<00:00,  6.32s/it]
# Evaluate 8: Time 3.392s (it:3.364s) Data:0.998s (it:0.799s) Loss 2.2332e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:13<00:00,  3.39s/it]
# Train 9: Time 6.273s (it:5.112s) Data:1.295s (it:1.148s) Loss 2.5455e+00 : 100%|████████████████████████████████████████████████| 57/57 [05:57<00:00,  6.27s/it]
# Evaluate 9: Time 3.326s (it:2.673s) Data:0.998s (it:0.830s) Loss 2.2488e+00 : 100%|█████████████████████████████████████████████| 57/57 [03:09<00:00,  3.33s/it]
# Train 10: Time 6.437s (it:5.456s) Data:1.354s (it:1.099s) Loss 2.6339e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:06<00:00,  6.44s/it]
# Evaluate 10: Time 3.313s (it:2.668s) Data:0.988s (it:0.799s) Loss 2.2329e+00 : 100%|████████████████████████████████████████████| 57/57 [03:08<00:00,  3.31s/it]
# Train 11: Time 6.274s (it:5.269s) Data:1.318s (it:1.070s) Loss 2.5706e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:57<00:00,  6.27s/it]
# Evaluate 11: Time 3.222s (it:4.169s) Data:0.971s (it:0.816s) Loss 2.1050e+00 : 100%|████████████████████████████████████████████| 57/57 [03:03<00:00,  3.22s/it]
# Train 12: Time 6.240s (it:5.358s) Data:1.239s (it:1.156s) Loss 2.5378e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:55<00:00,  6.24s/it]
# Evaluate 12: Time 3.458s (it:2.476s) Data:1.032s (it:0.813s) Loss 2.2131e+00 : 100%|████████████████████████████████████████████| 57/57 [03:17<00:00,  3.46s/it]
# Train 13: Time 6.443s (it:5.349s) Data:1.295s (it:1.153s) Loss 2.5088e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:07<00:00,  6.44s/it]
# Evaluate 13: Time 3.405s (it:2.648s) Data:1.018s (it:0.800s) Loss 2.3146e+00 : 100%|████████████████████████████████████████████| 57/57 [03:14<00:00,  3.41s/it]
# Train 14: Time 6.418s (it:6.871s) Data:1.315s (it:1.111s) Loss 2.5124e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:05<00:00,  6.42s/it]
# Evaluate 14: Time 3.283s (it:2.512s) Data:0.986s (it:0.831s) Loss 2.1104e+00 : 100%|████████████████████████████████████████████| 57/57 [03:07<00:00,  3.28s/it]
# Train 15: Time 6.471s (it:6.785s) Data:1.354s (it:1.123s) Loss 2.5524e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:08<00:00,  6.47s/it]
# Evaluate 15: Time 3.282s (it:6.521s) Data:0.972s (it:3.198s) Loss 2.0867e+00 : 100%|████████████████████████████████████████████| 57/57 [03:07<00:00,  3.28s/it]
# Train 16: Time 6.445s (it:7.083s) Data:1.254s (it:1.182s) Loss 2.4877e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:07<00:00,  6.44s/it]
# Evaluate 16: Time 3.411s (it:2.657s) Data:1.045s (it:0.799s) Loss 2.1570e+00 : 100%|████████████████████████████████████████████| 57/57 [03:14<00:00,  3.41s/it]
# Train 17: Time 6.392s (it:5.046s) Data:1.286s (it:1.107s) Loss 2.5928e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:04<00:00,  6.39s/it]
# Evaluate 17: Time 3.605s (it:3.929s) Data:1.024s (it:0.828s) Loss 2.2438e+00 : 100%|████████████████████████████████████████████| 57/57 [03:25<00:00,  3.60s/it]
# Train 18: Time 6.439s (it:6.881s) Data:1.305s (it:1.114s) Loss 2.4328e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:06<00:00,  6.44s/it]
# Evaluate 18: Time 3.426s (it:2.570s) Data:1.025s (it:0.779s) Loss 2.1321e+00 : 100%|████████████████████████████████████████████| 57/57 [03:15<00:00,  3.43s/it]
# Train 19: Time 6.611s (it:5.183s) Data:1.350s (it:1.132s) Loss 2.5207e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:16<00:00,  6.61s/it]
# Evaluate 19: Time 3.305s (it:3.460s) Data:0.987s (it:0.829s) Loss 2.2101e+00 : 100%|████████████████████████████████████████████| 57/57 [03:08<00:00,  3.31s/it]
# Train 20: Time 6.652s (it:5.441s) Data:1.368s (it:1.134s) Loss 2.5268e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:19<00:00,  6.65s/it]
# Evaluate 20: Time 3.437s (it:3.858s) Data:0.976s (it:0.800s) Loss 2.2444e+00 : 100%|████████████████████████████████████████████| 57/57 [03:15<00:00,  3.44s/it]
# Train 21: Time 6.281s (it:5.363s) Data:1.256s (it:1.171s) Loss 2.4248e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:57<00:00,  6.28s/it]
# Evaluate 21: Time 3.512s (it:2.876s) Data:1.024s (it:0.862s) Loss 2.1774e+00 : 100%|████████████████████████████████████████████| 57/57 [03:20<00:00,  3.51s/it]
# Train 22: Time 6.356s (it:5.403s) Data:1.283s (it:1.174s) Loss 2.5281e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:02<00:00,  6.36s/it]
# Evaluate 22: Time 3.471s (it:2.430s) Data:1.053s (it:0.788s) Loss 2.0440e+00 : 100%|████████████████████████████████████████████| 57/57 [03:17<00:00,  3.47s/it]
# Train 23: Time 6.381s (it:5.265s) Data:1.322s (it:1.141s) Loss 2.4646e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:03<00:00,  6.38s/it]
# Evaluate 23: Time 3.296s (it:2.750s) Data:1.024s (it:0.793s) Loss 2.1572e+00 : 100%|████████████████████████████████████████████| 57/57 [03:07<00:00,  3.30s/it]
# Train 24: Time 6.506s (it:6.682s) Data:1.317s (it:1.129s) Loss 2.5221e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:10<00:00,  6.51s/it]
# Evaluate 24: Time 3.379s (it:2.621s) Data:0.993s (it:0.823s) Loss 2.2194e+00 : 100%|████████████████████████████████████████████| 57/57 [03:12<00:00,  3.38s/it]
# Train 25: Time 6.373s (it:6.566s) Data:1.258s (it:1.092s) Loss 2.3863e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:03<00:00,  6.37s/it]
# Evaluate 25: Time 3.359s (it:2.706s) Data:1.019s (it:0.802s) Loss 2.2819e+00 : 100%|████████████████████████████████████████████| 57/57 [03:11<00:00,  3.36s/it]
# Train 26: Time 6.356s (it:7.506s) Data:1.245s (it:1.081s) Loss 2.5415e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:02<00:00,  6.36s/it]
# Evaluate 26: Time 3.330s (it:2.450s) Data:1.006s (it:0.776s) Loss 2.3555e+00 : 100%|████████████████████████████████████████████| 57/57 [03:09<00:00,  3.33s/it]
# Train 27: Time 6.281s (it:5.317s) Data:1.261s (it:1.135s) Loss 2.4696e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:58<00:00,  6.28s/it]
# Evaluate 27: Time 3.326s (it:2.769s) Data:1.023s (it:0.795s) Loss 2.3041e+00 : 100%|████████████████████████████████████████████| 57/57 [03:09<00:00,  3.33s/it]
# Train 28: Time 6.470s (it:6.893s) Data:1.317s (it:1.134s) Loss 2.4510e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:08<00:00,  6.47s/it]
# Evaluate 28: Time 3.311s (it:4.056s) Data:0.989s (it:0.803s) Loss 2.3387e+00 : 100%|████████████████████████████████████████████| 57/57 [03:08<00:00,  3.31s/it]
# Evaluate 54: Time 3.228s (it:2.767s) Data:1.031s (it:0.825s) Loss 2.0277e+00 : 100%|████████████████████████████████████████████| 57/57 [03:03<00:00,  3.23s/it]
# Train 55: Time 6.380s (it:5.866s) Data:1.289s (it:1.948s) Loss 2.3418e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:03<00:00,  6.38s/it]
# Evaluate 55: Time 3.288s (it:2.751s) Data:1.008s (it:0.785s) Loss 2.1336e+00 : 100%|████████████████████████████████████████████| 57/57 [03:07<00:00,  3.29s/it]
# Train 56: Time 6.356s (it:6.698s) Data:1.302s (it:1.073s) Loss 2.3683e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:02<00:00,  6.36s/it]
# Evaluate 56: Time 3.196s (it:2.419s) Data:0.975s (it:0.763s) Loss 2.0648e+00 : 100%|████████████████████████████████████████████| 57/57 [03:02<00:00,  3.20s/it]
# Train 57: Time 6.397s (it:4.960s) Data:1.322s (it:1.125s) Loss 2.3829e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:04<00:00,  6.40s/it]
# Evaluate 57: Time 3.314s (it:3.970s) Data:0.976s (it:0.784s) Loss 2.1165e+00 : 100%|████████████████████████████████████████████| 57/57 [03:08<00:00,  3.31s/it]
# Train 58: Time 6.416s (it:5.462s) Data:1.319s (it:1.181s) Loss 2.2377e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:05<00:00,  6.42s/it]
# Evaluate 58: Time 3.223s (it:2.698s) Data:0.944s (it:0.805s) Loss 1.9262e+00 : 100%|████████████████████████████████████████████| 57/57 [03:03<00:00,  3.22s/it]
# Train 59: Time 24.908s (it:6.739s) Data:19.469s (it:1.143s) Loss 2.3799e+00 : 100%|█████████████████████████████████████████████| 57/57 [23:39<00:00, 24.91s/it]
# Evaluate 59: Time 21.790s (it:2.779s) Data:1.060s (it:0.892s) Loss 2.0280e+00 : 100%|███████████████████████████████████████████| 57/57 [20:42<00:00, 21.79s/it]
# Train 60: Time 6.442s (it:6.492s) Data:1.289s (it:1.135s) Loss 2.4797e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:07<00:00,  6.44s/it]
# Evaluate 60: Time 3.531s (it:2.812s) Data:1.022s (it:0.839s) Loss 2.0325e+00 : 100%|████████████████████████████████████████████| 57/57 [03:21<00:00,  3.53s/it]
# Train 61: Time 6.534s (it:5.415s) Data:1.336s (it:1.143s) Loss 2.4045e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:12<00:00,  6.53s/it]
# Evaluate 61: Time 3.501s (it:3.719s) Data:1.016s (it:0.767s) Loss 2.0706e+00 : 100%|████████████████████████████████████████████| 57/57 [03:19<00:00,  3.50s/it]
# Train 62: Time 6.413s (it:6.648s) Data:1.349s (it:1.062s) Loss 2.3069e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:05<00:00,  6.41s/it]
# Evaluate 62: Time 3.284s (it:2.634s) Data:0.953s (it:0.824s) Loss 1.9866e+00 : 100%|████████████████████████████████████████████| 57/57 [03:07<00:00,  3.28s/it]
# Train 63: Time 6.591s (it:6.315s) Data:1.292s (it:1.136s) Loss 2.3283e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:15<00:00,  6.59s/it]
# Evaluate 63: Time 3.488s (it:2.502s) Data:1.029s (it:0.803s) Loss 2.1878e+00 : 100%|████████████████████████████████████████████| 57/57 [03:18<00:00,  3.49s/it]
# Train 64: Time 6.618s (it:5.293s) Data:1.303s (it:1.123s) Loss 2.3408e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:17<00:00,  6.62s/it]
# Evaluate 64: Time 3.520s (it:3.648s) Data:1.035s (it:0.793s) Loss 2.0288e+00 : 100%|████████████████████████████████████████████| 57/57 [03:20<00:00,  3.52s/it]
# Train 65: Time 6.604s (it:5.783s) Data:1.338s (it:1.201s) Loss 2.3557e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:16<00:00,  6.60s/it]
# Evaluate 65: Time 3.516s (it:3.570s) Data:1.009s (it:0.905s) Loss 2.1307e+00 : 100%|████████████████████████████████████████████| 57/57 [03:20<00:00,  3.52s/it]
# Train 66: Time 48.565s (it:6.848s) Data:1.360s (it:1.105s) Loss 2.4023e+00 : 100%|██████████████████████████████████████████████| 57/57 [46:08<00:00, 48.57s/it]
# Evaluate 66: Time 3.244s (it:2.575s) Data:0.968s (it:0.759s) Loss 2.1337e+00 : 100%|████████████████████████████████████████████| 57/57 [03:04<00:00,  3.24s/it]
# Train 67: Time 6.453s (it:6.158s) Data:1.345s (it:1.145s) Loss 2.3559e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:07<00:00,  6.45s/it]
# Evaluate 67: Time 3.313s (it:3.923s) Data:0.940s (it:0.786s) Loss 2.1263e+00 : 100%|████████████████████████████████████████████| 57/57 [03:08<00:00,  3.31s/it]
# Train 68: Time 6.337s (it:5.329s) Data:1.313s (it:1.109s) Loss 2.4792e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:01<00:00,  6.34s/it]
# Evaluate 68: Time 3.393s (it:2.688s) Data:1.041s (it:0.832s) Loss 2.0313e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.39s/it]
# Train 69: Time 6.326s (it:5.403s) Data:1.295s (it:1.146s) Loss 2.3500e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:00<00:00,  6.33s/it]
# Evaluate 69: Time 3.645s (it:2.873s) Data:1.030s (it:0.880s) Loss 2.0506e+00 : 100%|████████████████████████████████████████████| 57/57 [03:27<00:00,  3.65s/it]
# Train 70: Time 7.093s (it:7.214s) Data:1.462s (it:1.181s) Loss 2.2690e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:44<00:00,  7.09s/it]
# Evaluate 70: Time 4.688s (it:4.343s) Data:1.195s (it:0.976s) Loss 2.2001e+00 : 100%|████████████████████████████████████████████| 57/57 [04:27<00:00,  4.69s/it]
# Train 71: Time 7.110s (it:5.090s) Data:1.488s (it:1.168s) Loss 2.3382e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:45<00:00,  7.11s/it]
# Evaluate 71: Time 3.509s (it:3.327s) Data:0.951s (it:0.870s) Loss 2.0357e+00 : 100%|████████████████████████████████████████████| 57/57 [03:20<00:00,  3.51s/it]
# Train 72: Time 6.613s (it:6.632s) Data:1.314s (it:1.171s) Loss 2.2863e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:16<00:00,  6.61s/it]
# Evaluate 72: Time 3.535s (it:2.558s) Data:1.037s (it:0.855s) Loss 2.1431e+00 : 100%|████████████████████████████████████████████| 57/57 [03:21<00:00,  3.54s/it]
# Train 73: Time 6.604s (it:5.079s) Data:1.331s (it:1.166s) Loss 2.3642e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:16<00:00,  6.60s/it]
# Evaluate 73: Time 4.433s (it:2.796s) Data:1.159s (it:0.872s) Loss 2.0373e+00 : 100%|████████████████████████████████████████████| 57/57 [04:12<00:00,  4.43s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
#  Pass
# Data preprocessing: 100%|██████████| 10/10 [03:03<00:00, 18.30s/it]
# Get labels & features: 100%|██████████| 40/40 [12:44<00:00, 19.12s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# ...
# Evaluate 12: Time 3.503s (it:2.722s) Data:1.060s (it:0.815s) Loss 4.2919e+00 : 100%|████████████████████████████████████████████| 57/57 [03:19<00:00,  3.50s/it]
# Train 13: Time 6.402s (it:5.376s) Data:1.381s (it:1.163s) Loss 3.6174e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:04<00:00,  6.40s/it]
# Evaluate 13: Time 3.346s (it:2.693s) Data:0.956s (it:0.829s) Loss 4.0033e+00 : 100%|████████████████████████████████████████████| 57/57 [03:10<00:00,  3.35s/it]
# Train 14: Time 6.433s (it:5.156s) Data:1.352s (it:1.174s) Loss 3.5582e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:06<00:00,  6.43s/it]
# Evaluate 14: Time 3.401s (it:2.510s) Data:1.064s (it:0.821s) Loss 4.1725e+00 : 100%|████████████████████████████████████████████| 57/57 [03:13<00:00,  3.40s/it]
# Train 15: Time 6.387s (it:5.317s) Data:1.392s (it:1.146s) Loss 3.5488e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:04<00:00,  6.39s/it]
# Evaluate 15: Time 3.414s (it:2.719s) Data:1.030s (it:0.824s) Loss 4.2806e+00 : 100%|████████████████████████████████████████████| 57/57 [03:14<00:00,  3.41s/it]
# Train 16: Time 6.351s (it:5.202s) Data:1.309s (it:1.169s) Loss 3.5468e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:02<00:00,  6.35s/it]
# Evaluate 16: Time 3.420s (it:2.882s) Data:1.049s (it:0.778s) Loss 4.1305e+00 : 100%|████████████████████████████████████████████| 57/57 [03:14<00:00,  3.42s/it]
# Train 17: Time 6.301s (it:6.810s) Data:1.339s (it:1.211s) Loss 3.5719e+00 : 100%|███████████████████████████████████████████████| 57/57 [05:59<00:00,  6.30s/it]
# Evaluate 17: Time 3.485s (it:2.735s) Data:1.056s (it:0.797s) Loss 4.1409e+00 : 100%|████████████████████████████████████████████| 57/57 [03:18<00:00,  3.49s/it]
# Train 61: Time 6.480s (it:5.308s) Data:1.392s (it:1.172s) Loss 3.1547e+00 : 100%|███████████████████████████████████████████████| 57/57 [06:09<00:00,  6.48s/it]
# Evaluate 61: Time 3.574s (it:2.756s) Data:1.051s (it:0.870s) Loss 4.1900e+00 : 100%|████████████████████████████████████████████| 57/57 [03:23<00:00,  3.57s/it]

# %%
args = Args

precisions_combined = np.empty(0)
recalls_combined = np.empty(0)
f1_combined = np.empty(0)

prediction_x_data = []
prediction_y_data = []

annotation_x_data = []
annotation_y_data = []

for i, ann in enumerate(event_enc.keys()):

    args.focused_annotation = ann

    model_path = f"models/finetuned_{ann}.pth.tar"
    model = torch.load(model_path)
    game_analyser = GamaAnalysis(args, model)
    results, annotations = game_analyser.predict_game(game_index=0, seg_model=True, calibrate=False, ann=ann)
    fig, ax = game_analyser.plot_predictions(frame_threshold=20000, save_dir=None, annotation=ann)
    
    prediction_x_data.append(ax.get_lines()[0].get_xdata()) 
    prediction_y_data.append(ax.get_lines()[0].get_ydata())

    annotation_x_data.append(ax.get_lines()[1].get_xdata()) 
    annotation_y_data.append(ax.get_lines()[1].get_ydata())

    precision, recall, f1_score, _ = game_analyser.segmentation_evaluation(ann)

    precisions_combined = np.concatenate((precisions_combined, precision), axis=0)
    recalls_combined = np.concatenate((recalls_combined, recall), axis=0)
    f1_combined = np.concatenate((f1_combined, f1_score), axis=0)


precisions_combined = np.concatenate((np.array([np.mean(precisions_combined)]), precisions_combined), axis=0)
recalls_combined = np.concatenate((np.array([np.mean(recalls_combined)]), recalls_combined), axis=0)
f1_combined = np.concatenate((np.array([np.mean(f1_combined)]), f1_combined), axis=0)
# Out:
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:07<00:00,  7.44s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:08<00:00,  8.75s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:09<00:00,  9.28s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:09<00:00,  9.27s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:09<00:00,  9.26s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:09<00:00,  9.08s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:09<00:00,  9.35s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:09<00:00,  9.25s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:09<00:00,  9.37s/it]
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-BRA/Reports Bel-Bra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-FRA/Reports Bel-Fra does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-ENG_3rd_place_final/Reports Bel-Eng does not contain xml file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain dat file
# WARNING:root:../football_games/WC2018/BEL-JAP/Reports Bel-Jan does not contain xml file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain dat file
# WARNING:root:../football_games/WC2018 qualification&friendlies/BEL-SAU_no raw does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CAN/TRACKING_DATA_20221123_BEL-CAN does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-MOR/TRACKING_DATA_20221127_BEL-MAR does not contain xml file
# WARNING:root:../football_games/WC2022/BEL-CRO/TRACKING_DATA_20221201_CRO-BEL does not contain xml file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain dat file
# WARNING:root:../football_games/EC2024 qualification&friendlies/GER-BEL/rbfa_runs-johan_2023-09-10_0958/Runs Johan does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030760 - Tracking raw data/post.samples.ball does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.centroids does not contain xml file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain dat file
# WARNING:root:../football_games/NL2020/Datafeed - 20232 - 2030759 - Tracking raw data/post.samples.ball does not contain xml file
# Data preprocessing: 100%|██████████| 1/1 [00:09<00:00,  9.39s/it]

# %%
cols = ["Total"] + list(event_enc.keys())
rows = ["Precision", "Recall", "F1-score"]

fig = plt.figure(figsize=(20, 2))

total_scores = np.concatenate((precisions_combined, recalls_combined, f1_combined))

# ax1.set_title("Precision scores")
ax = sns.heatmap(total_scores.reshape(3,-1), annot=True, cmap="coolwarm", fmt=".2f", xticklabels=True, yticklabels=True)
ax.set_xticklabels(cols, rotation=0)
ax.xaxis.tick_top()
ax.set_yticklabels(rows, rotation=0)

plt.title("Evaluation of fine-tuned models")
plt.show()

# %%
fig, axes = plt.subplots(5, 2, figsize=(20, 20))
axes_flattened = axes.flatten()

for i, ax in enumerate(axes_flattened):
    ax.plot(prediction_x_data[i], prediction_y_data[i], label="Predictions")
    ax.plot(annotation_x_data[i], annotation_y_data[i], label="Annotations")
    ax.set_title(list(event_enc)[i])

plt.legend()
plt.show()
